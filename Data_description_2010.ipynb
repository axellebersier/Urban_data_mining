# %% [markdown]
# <a href="https://colab.research.google.com/github/axellebersier/Urban_data_mining/blob/main/Data_description_2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Data Processing**

# %% [markdown]
# ##Data description

# %% [markdown]
# Set up and load the data

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
rnd_seed = 42
rnd_gen = np.random.default_rng(rnd_seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "dim_reduction"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import pandas as pd

url = 'https://github.com/axellebersier/Urban_data_mining/blob/main/Data/data_2010.xlsx?raw=true'
df_2020 = pd.read_excel(url)

# %% [markdown]
# ##Data Description 2020

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2144 entries, 0 to 2143
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2144 non-null   int64
#  1   migration            2144 non-null   float64
#  2   migration_intern     2144 non-null   float64
#  3   dependency_ratio     2144 non-null   float64
#  4   Population           2144 non-null   float64
#  5   p_new_housings       2144 non-null   float64
#  6   p_new_buildings      2144 non-null   float64
#  7   p_weddings           2144 non-null   float64
#  8   p_individual_houses  2143 non-null   float64
#  9   p_foreigners         2144 non-null   float64
#  10  density              2144 non-null   float64
#  11  p_social_assistance  2144 non-null   float64
#  12  natural_growth_1000  2144 non-null   float64
#  13  p_infrastructure     2144 non-null   float64
#  14  p_forested           2144 non-null   float64
#  15  p_agriculture        2144 non-null   float64
#  16  p_improductible      2144 non-null   float64
#  17  surface_polygone     2144 non-null   float64
#  18  p_surf_transport     2144 non-null   float64
#  19  zab_2012             2131 non-null   float64
#  20  net_income_h         2144 non-null   float64
#  21  p_pop_19             2144 non-null   float64
#  22  p_pop_65             2144 non-null   float64
#  23  p_primary_sector     2144 non-null   float64
#  24  p_secondary_sector   2144 non-null   float64
#  25  p_tertiary_sector    2144 non-null   float64
# dtypes: float64(25), int64(1)
# memory usage: 435.6 KB

# %%
df_2020 = df_2020.rename(columns={'p_improductible': 'p_unproductive'})
df_2020 = df_2020.rename(columns={'p_new_entreprise': 'p_new_enterprise'})
df_2020.describe()
# Out:
#                 ID    migration  migration_intern  dependency_ratio  \
# count  2144.000000  2144.000000       2144.000000       2144.000000
# mean   3288.834422     5.653833          1.950193         63.835275
# std    2133.946019     8.288014         19.707229          8.788860
# min       1.000000   -63.829787       -145.161290         23.255814
# 25%    1066.750000     1.254471         -8.366711         58.355798
# 50%    3295.500000     4.788532          0.278515         63.280314
# 75%    5411.250000     8.871877          9.986715         68.714891
# max    6810.000000    77.348066        155.979203        141.176471
#
#           Population  p_new_housings  p_new_buildings   p_weddings  \
# count    2144.000000     2144.000000      2144.000000  2144.000000
# mean     3408.279967        5.477099         2.898458     4.984449
# std     11553.550499        7.393927         3.570477     2.862430
# min        33.000000        0.000000         0.000000     0.000000
# 25%       652.750000        1.010741         0.646183     3.488169
# 50%      1357.000000        3.184120         1.932554     4.877187
# 75%      3236.000000        7.318246         3.938543     6.174747
# max    372857.000000      110.344828        58.823529    51.282051
#
#        p_individual_houses  p_foreigners  ...  p_unproductive  \
# count          2143.000000   2144.000000  ...     2144.000000
# mean             60.026546     14.109551  ...        0.066076
# std              13.609583      9.332261  ...        0.140029
# min              10.037175      0.000000  ...        0.000000
# 25%              51.846469      7.201368  ...        0.003253
# 50%              61.538462     11.680808  ...        0.011210
# 75%              69.807621     19.273386  ...        0.046798
# max              95.041322     60.640792  ...        0.949945
#
#        surface_polygone  p_surf_transport     zab_2012   net_income_h  \
# count       2144.000000       2144.000000  2131.000000    2144.000000
# mean        1847.649995          4.242450   107.068264   36144.225066
# std         3351.358160          3.794649   178.816952   12851.281634
# min           31.000000          0.000000     0.000000   11198.850575
# 25%          441.750000          1.922189    28.525000   29979.273919
# 50%          831.000000          3.116919    59.670000   33659.361939
# 75%         1680.250000          5.283335   127.560000   38747.020439
# max        43861.000000         41.876430  4779.200000  339140.935673
#
#           p_pop_19     p_pop_65  p_primary_sector  p_secondary_sector  \
# count  2144.000000  2144.000000       2144.000000         2144.000000
# mean     22.291621    16.489898          0.166866            0.265748
# std       3.579937     3.927373          0.170464            0.164197
# min       2.040816     5.347594          0.000000            0.000000
# 25%      20.164554    13.815442          0.032640            0.146687
# 50%      22.268500    16.095125          0.105512            0.246566
# 75%      24.529185    18.789427          0.252612            0.361679
# max      43.902439    40.625000          1.000000            0.946816
#
#        p_tertiary_sector
# count        2144.000000
# mean            0.546604
# std             0.204310
# min             0.000000
# 25%             0.407109
# 50%             0.558214
# 75%             0.695310
# max             0.976763
#
# [8 rows x 26 columns]

# %%
w_pop = df_2020.iloc[:, 4].tolist()  # the column of the population

w_surf = df_2020.iloc[:, 17].tolist() # the column of the surface

# %%
print(df_2020.columns)
#df_2020.drop('Population', axis=1, inplace=True)
#df_2020.drop('surface_polygone', axis=1, inplace=True)
# Out:
# Index(['ID', 'migration', 'migration_intern', 'dependency_ratio', 'Population',
#        'p_new_housings', 'p_new_buildings', 'p_weddings',
#        'p_individual_houses', 'p_foreigners', 'density', 'p_social_assistance',
#        'natural_growth_1000', 'p_infrastructure', 'p_forested',
#        'p_agriculture', 'p_unproductive', 'surface_polygone',
#        'p_surf_transport', 'zab_2012', 'net_income_h', 'p_pop_19', 'p_pop_65',
#        'p_primary_sector', 'p_secondary_sector', 'p_tertiary_sector'],
#       dtype='object')

# %%
df_2020.head()
# Out:
#    ID  migration  migration_intern  dependency_ratio  Population  \
# 0   1   1.684447         38.180797         58.333333      1824.0
# 1   2   6.267859          9.217439         58.352370     11091.0
# 2   3   3.707317         -3.121951         55.625943      5159.0
# 3   4   1.799640          3.299340         60.228898      3360.0
# 4   5   2.053991         -2.347418         58.752328      3410.0
#
#    p_new_housings  p_new_buildings  p_weddings  p_individual_houses  \
# 0       31.250000         7.127193    2.245929            71.910112
# 1        9.917951         1.442611    6.083510            57.195572
# 2        3.295212         3.295212    6.243902            72.362278
# 3        2.380952         2.083333    3.899220            70.070779
# 4        4.985337         2.346041    6.161972            76.811594
#
#    p_foreigners  ...  p_unproductive  surface_polygone  p_surf_transport  \
# 0     12.335526  ...        0.053097             791.0          4.955527
# 1     25.534217  ...        0.009443            1059.0          6.603774
# 2     12.735026  ...        0.004038             743.0          5.369128
# 3     11.636905  ...        0.025735            1360.0          4.605263
# 4     13.225806  ...        0.006126             653.0          5.053599
#
#    zab_2012  net_income_h   p_pop_19   p_pop_65  p_primary_sector  \
# 0     61.01  55747.276811  21.600877  15.241228          0.097403
# 1    285.84  35913.245460  21.765395  15.084303          0.013532
# 2     93.01  45505.424390  23.841830  11.901531          0.043575
# 3    119.71  42562.537493  23.511905  14.077381          0.113660
# 4    102.76  44153.579812  24.780059  12.228739          0.022413
#
#    p_secondary_sector  p_tertiary_sector
# 0            0.030303           0.872294
# 1            0.220061           0.766407
# 2            0.127374           0.829050
# 3            0.118874           0.767466
# 4            0.502966           0.474621
#
# [5 rows x 26 columns]

# %%
df_2020.drop('p_infrastructure', axis=1, inplace=True)
df_2020.drop('p_weddings', axis=1, inplace=True)
df_2020.drop('p_tertiary_sector', axis=1, inplace=True)
df_2020.drop('p_pop_65', axis=1, inplace=True)

# %%
df_ID =  df_2020.iloc[:,0]
df_2020 =  df_2020.iloc[:,1:]
df_2020
# Out:
#       migration  migration_intern  dependency_ratio    Population  \
# 0      1.684447         38.180797         58.333333   1824.000000
# 1      6.267859          9.217439         58.352370  11091.000000
# 2      3.707317         -3.121951         55.625943   5159.000000
# 3      1.799640          3.299340         60.228898   3360.000000
# 4      2.053991         -2.347418         58.752328   3410.000000
# ...         ...               ...               ...           ...
# 2139   0.000000          7.339450         81.188119    549.000000
# 2140   3.046458         -9.900990         81.527778   1307.000000
# 2141   5.417957        -29.411765         75.138889   1261.000000
# 2142   2.645503         -8.597884         69.707021    717.666667
# 2143   4.180602         -8.361204         78.528529   1189.000000
#
#       p_new_housings  p_new_buildings  p_individual_houses  p_foreigners  \
# 0          31.250000         7.127193            71.910112     12.335526
# 1           9.917951         1.442611            57.195572     25.534217
# 2           3.295212         3.295212            72.362278     12.735026
# 3           2.380952         2.083333            70.070779     11.636905
# 4           4.985337         2.346041            76.811594     13.225806
# ...              ...              ...                  ...           ...
# 2139        3.642987         3.642987            69.268293      9.107468
# 2140        4.590666         3.825555            76.524954      7.039021
# 2141        0.793021         0.793021            59.167951      6.264869
# 2142        6.250293         6.250293            75.289212      5.568249
# 2143        1.682086         1.682086            68.141593      5.803196
#
#           density  p_social_assistance  ...  p_forested  p_agriculture  \
# 0      230.594185             0.917960  ...    0.307206       0.513274
# 1     1045.334590             3.651060  ...    0.279509       0.401322
# 2      694.347241             0.391160  ...    0.286676       0.553163
# 3      246.696035             0.511280  ...    0.289706       0.560294
# 4      522.205207             0.937590  ...    0.333844       0.465544
# ...           ...                  ...  ...         ...            ...
# 2139    59.803922             1.102940  ...    0.373770       0.561749
# 2140    56.702820             1.058200  ...    0.472656       0.446181
# 2141    20.414441             1.067070  ...    0.520162       0.430283
# 2142    29.955989             0.524933  ...    0.394332       0.565111
# 2143    38.268426             0.579950  ...    0.456711       0.490827
#
#       p_unproductive  surface_polygone  p_surf_transport  zab_2012  \
# 0           0.053097             791.0          4.955527     61.01
# 1           0.009443            1059.0          6.603774    285.84
# 2           0.004038             743.0          5.369128     93.01
# 3           0.025735            1360.0          4.605263    119.71
# 4           0.006126             653.0          5.053599    102.76
# ...              ...               ...               ...       ...
# 2139        0.002186             915.0          2.069717     38.12
# 2140        0.006510            2304.0          2.783819     82.34
# 2141        0.013441            6175.0          2.021999     81.79
# 2142        0.000489            4093.0          1.470487     98.63
# 2143        0.004184            3107.0          1.446480     95.90
#
#       net_income_h   p_pop_19  p_primary_sector  p_secondary_sector
# 0     55747.276811  21.600877          0.097403            0.030303
# 1     35913.245460  21.765395          0.013532            0.220061
# 2     45505.424390  23.841830          0.043575            0.127374
# 3     42562.537493  23.511905          0.113660            0.118874
# 4     44153.579812  24.780059          0.022413            0.502966
# ...            ...        ...               ...                 ...
# 2139  27290.275229  24.225865          0.136364            0.691919
# 2140  29102.208682  22.570773          0.292776            0.439163
# 2141  26181.191950  20.142744          0.317439            0.224796
# 2142  28491.604715  20.779138          0.223975            0.506309
# 2143  28428.929766  24.810765          0.245322            0.230769
#
# [2144 rows x 21 columns]

# %%
df_2020 = pd.DataFrame(df_2020)
corr_matrix_2020 = df_2020.corr()

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2144 entries, 0 to 2143
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   migration            2144 non-null   float64
#  1   migration_intern     2144 non-null   float64
#  2   dependency_ratio     2144 non-null   float64
#  3   Population           2144 non-null   float64
#  4   p_new_housings       2144 non-null   float64
#  5   p_new_buildings      2144 non-null   float64
#  6   p_individual_houses  2143 non-null   float64
#  7   p_foreigners         2144 non-null   float64
#  8   density              2144 non-null   float64
#  9   p_social_assistance  2144 non-null   float64
#  10  natural_growth_1000  2144 non-null   float64
#  11  p_forested           2144 non-null   float64
#  12  p_agriculture        2144 non-null   float64
#  13  p_unproductive       2144 non-null   float64
#  14  surface_polygone     2144 non-null   float64
#  15  p_surf_transport     2144 non-null   float64
#  16  zab_2012             2131 non-null   float64
#  17  net_income_h         2144 non-null   float64
#  18  p_pop_19             2144 non-null   float64
#  19  p_primary_sector     2144 non-null   float64
#  20  p_secondary_sector   2144 non-null   float64
# dtypes: float64(21)
# memory usage: 351.9 KB

# %% [markdown]
# Replace the outliers by the median

# %%
# calculate the boundaries
lower_bound = df_2020.mean() - 3 * df_2020.std()
upper_bound = df_2020.mean() + 3 * df_2020.std()

# replace the outliers by the median
for column in df_2020.columns:
    median = df_2020[column].median()
    df_2020.loc[df_2020[column] < lower_bound[column], column] = median
    df_2020.loc[df_2020[column] > upper_bound[column], column] = median

# %%
from sklearn.preprocessing import StandardScaler
nostdf_2020 = df_2020

scaler = StandardScaler()
stdf_2020 = scaler.fit_transform(df_2020)

df_2020 = pd.DataFrame(data=stdf_2020, columns=df_2020.columns)
df_2020['ID'] = df_ID


df_2020.to_csv('data_scaled_2010.csv', index = False, sep=',')
df_2020
# Out:
#       migration  migration_intern  dependency_ratio  Population  \
# 0     -0.546101          2.241058         -0.660898   -0.239396
# 1      0.139013          0.478503         -0.658511    2.079151
# 2     -0.243728         -0.272406         -1.000414    0.595000
# 3     -0.528882          0.118359         -0.423188    0.144902
# 4     -0.490862         -0.225272         -0.608355    0.157411
# ...         ...               ...               ...         ...
# 2139  -0.797887          0.364219          2.205168   -0.558394
# 2140  -0.342511         -0.684942          2.247762   -0.368747
# 2141   0.011973         -1.872263          1.446574   -0.380255
# 2142  -0.402445         -0.605642          0.765400   -0.516194
# 2143  -0.172983         -0.591239          1.871646   -0.398269
#
#       p_new_housings  p_new_buildings  p_individual_houses  p_foreigners  \
# 0          -0.307513         1.752654             0.880573     -0.153229
# 1           0.991672        -0.437349            -0.230200      1.394551
# 2          -0.286079         0.276371             0.914706     -0.106380
# 3          -0.462471        -0.190509             0.741725     -0.235154
# 4           0.040003        -0.089300             1.250576     -0.048827
# ...              ...              ...                  ...           ...
# 2139       -0.218982         0.410353             0.681147     -0.531775
# 2140       -0.036143         0.480687             1.228938     -0.774338
# 2141       -0.768837        -0.687605            -0.081309     -0.865120
# 2142        0.284056         1.414825             1.135654     -0.946812
# 2143       -0.597306        -0.345091             0.596094     -0.919260
#
#        density  p_social_assistance  ...  p_agriculture  p_unproductive  \
# 0    -0.224832            -0.345541  ...       0.282056        0.119495
# 1     1.740859             1.740056  ...      -0.304420       -0.404882
# 2     0.894046            -0.747536  ...       0.491016       -0.469809
# 3    -0.185984            -0.655874  ...       0.528374       -0.209178
# 4     0.478726            -0.330561  ...       0.032013       -0.444729
# ...        ...                  ...  ...            ...             ...
# 2139 -0.636891            -0.204385  ...       0.535994       -0.492054
# 2140 -0.644373            -0.238525  ...      -0.069423       -0.440107
# 2141 -0.731924            -0.231757  ...      -0.152702       -0.356853
# 2142 -0.708904            -0.645455  ...       0.553609       -0.512440
# 2143 -0.688848            -0.603472  ...       0.164463       -0.468050
#
#       surface_polygone  p_surf_transport  zab_2012  net_income_h  p_pop_19  \
# 0            -0.359324          0.365369 -0.332713      2.585506 -0.241655
# 1            -0.207112          0.932493  1.901776      0.109704 -0.191425
# 2            -0.386585          0.507679 -0.014678      1.307057  0.442543
# 3            -0.036158          0.244851  0.250681      0.939709  0.341811
# 4            -0.437701          0.399113  0.082223      1.138312  0.728998
# ...                ...               ...       ...           ...       ...
# 2139         -0.288897         -0.627574 -0.560207     -0.966666  0.559795
# 2140          0.499990         -0.381868 -0.120723     -0.740490  0.054469
# 2141          2.698538         -0.643993 -0.126189     -1.105109 -0.686846
# 2142          1.516059         -0.833756  0.041176     -0.816709 -0.492545
# 2143          0.956057         -0.842016  0.014044     -0.824533  0.738374
#
#       p_primary_sector  p_secondary_sector    ID
# 0            -0.393022           -1.468364     1
# 1            -0.920133           -0.264820     2
# 2            -0.731315           -0.852687     3
# 3            -0.290847           -0.906602     4
# 4            -0.864319            1.529515     5
# ...                ...                 ...   ...
# 2139         -0.148159            2.727952  6806
# 2140          0.834860            1.124843  6807
# 2141          0.989862           -0.234790  6808
# 2142          0.402460            1.550716  6809
# 2143          0.536624           -0.196902  6810
#
# [2144 rows x 22 columns]

# %% [markdown]
# For SOM

# %%
from sklearn.preprocessing import MinMaxScaler

# Créer une instance de MinMaxScaler
scaler = MinMaxScaler()
# Appliquer la mise à l'échelle min-max aux données
scaled_data_SOM = scaler.fit_transform(nostdf_2020)

scaled_data_SOM = pd.DataFrame(data=scaled_data_SOM, columns = nostdf_2020.columns)
scaled_data_SOM['ID'] = df_ID
scaled_data_SOM.to_csv('scaled_data_SOM_2010.csv', index = False, sep=',')
scaled_data_SOM
# Out:
#       migration  migration_intern  dependency_ratio  Population  \
# 0      0.431487          0.806637          0.401017    0.047797
# 1      0.526348          0.560948          0.401384    0.295108
# 2      0.473354          0.456276          0.348761    0.136799
# 3      0.433871          0.510746          0.437603    0.088789
# 4      0.439135          0.462846          0.409104    0.090123
# ...         ...               ...               ...         ...
# 2139   0.396625          0.545017          0.842141    0.013771
# 2140   0.459676          0.398771          0.848697    0.034000
# 2141   0.508758          0.233266          0.725384    0.032772
# 2142   0.451378          0.409825          0.620542    0.018272
# 2143   0.483149          0.411833          0.790808    0.030851
#
#       p_new_housings  p_new_buildings  p_individual_houses  p_foreigners  \
# 0           0.116024         0.525037             0.694994      0.303309
# 1           0.361394         0.106272             0.500969      0.627842
# 2           0.120072         0.242747             0.700956      0.313132
# 3           0.086758         0.153472             0.670740      0.286131
# 4           0.181657         0.172825             0.759624      0.325200
# ...              ...              ...                  ...           ...
# 2139        0.132744         0.268367             0.660159      0.223937
# 2140        0.167276         0.281816             0.755844      0.173077
# 2141        0.028896         0.058419             0.526976      0.154042
# 2142        0.227750         0.460438             0.739550      0.136914
# 2143        0.061292         0.123914             0.645302      0.142691
#
#        density  p_social_assistance  ...  p_agriculture  p_unproductive  \
# 0     0.088872             0.149067  ...       0.565649        0.112348
# 1     0.404041             0.592893  ...       0.442273        0.019980
# 2     0.268267             0.063520  ...       0.609608        0.008543
# 3     0.095101             0.083026  ...       0.617467        0.054453
# 4     0.201677             0.152254  ...       0.513048        0.012961
# ...        ...                  ...  ...            ...             ...
# 2139  0.022805             0.179105  ...       0.619070        0.004625
# 2140  0.021605             0.171840  ...       0.491709        0.013775
# 2141  0.007568             0.173281  ...       0.474190        0.028440
# 2142  0.011259             0.085243  ...       0.622776        0.001034
# 2143  0.014474             0.094178  ...       0.540912        0.008853
#
#       surface_polygone  p_surf_transport  zab_2012  net_income_h  p_pop_19  \
# 0             0.064478          0.321440  0.096185      0.707299  0.479281
# 1             0.087215          0.428353  0.450638      0.392393  0.487361
# 2             0.060406          0.348268  0.146634      0.544689  0.589340
# 3             0.112751          0.298720  0.188728      0.497964  0.573137
# 4             0.052770          0.327801  0.162005      0.523225  0.635419
# ...                ...               ...       ...           ...       ...
# 2139          0.074998          0.134252  0.060098      0.255485  0.608201
# 2140          0.192840          0.180572  0.129812      0.284253  0.526915
# 2141          0.521252          0.131157  0.128945      0.237876  0.407668
# 2142          0.344617          0.095383  0.155494      0.274559  0.438923
# 2143          0.260965          0.093826  0.151190      0.273564  0.636927
#
#       p_primary_sector  p_secondary_sector    ID
# 0             0.144628            0.040616     1
# 1             0.020093            0.294957     2
# 2             0.064703            0.170725     3
# 3             0.168768            0.159332     4
# 4             0.033279            0.674148     5
# ...                ...                 ...   ...
# 2139          0.202479            0.927410  6806
# 2140          0.434728            0.588630  6807
# 2141          0.471348            0.301304  6808
# 2142          0.332569            0.678629  6809
# 2143          0.364266            0.309310  6810
#
# [2144 rows x 22 columns]

# %% [markdown]
# ##Description of the correlations for 2020

# %% [markdown]
# Correlation matrix

# %%
import seaborn as sn
import matplotlib.pyplot as plt

ax = sn.heatmap(corr_matrix_2020, annot=True)
plt.title("Heatmap of correlations")
plt.rcParams["figure.figsize"] = (30,50)
plt.show()

# %% [markdown]
# Principal component Analysis => cf code in R

# %% [markdown]
# Extract the data with the z-score

# %%
df_2020.to_csv('data_scaled_2010.csv', index = False, sep=',')

# %% [markdown]
# ##Number of clusters

# %% [markdown]
# delete the weights

# %%
df_2020.drop('Population', axis=1, inplace=True)
df_2020.drop('surface_polygone', axis=1, inplace=True)

# %% [markdown]
# Silhouette score

# %% [markdown]
# set up to do a K-Means analysis

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Data preprocessing and standardization

# %%
nostdf_2020 = df_2020

scaler = StandardScaler()
stdf_2020 = scaler.fit_transform(df_2020)

df_2020 = pd.DataFrame(stdf_2020)
print(df_2020)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.546101  2.241058 -0.660898 -0.307513  1.752654  0.880573 -0.153229
# 1     0.139013  0.478503 -0.658511  0.991672 -0.437349 -0.230200  1.394551
# 2    -0.243728 -0.272406 -1.000414 -0.286079  0.276371  0.914706 -0.106380
# 3    -0.528882  0.118359 -0.423188 -0.462471 -0.190509  0.741725 -0.235154
# 4    -0.490862 -0.225272 -0.608355  0.040003 -0.089300  1.250576 -0.048827
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.797887  0.364219  2.205168 -0.218982  0.410353  0.681147 -0.531775
# 2140 -0.342511 -0.684942  2.247762 -0.036143  0.480687  1.228938 -0.774338
# 2141  0.011973 -1.872263  1.446574 -0.768837 -0.687605 -0.081309 -0.865120
# 2142 -0.402445 -0.605642  0.765400  0.284056  1.414825  1.135654 -0.946812
# 2143 -0.172983 -0.591239  1.871646 -0.597306 -0.345091  0.596094 -0.919260
#
#             7         8         9         10        11        12        13  \
# 0    -0.224832 -0.345541  0.691208 -0.092141  0.282056  0.119495  0.365369
# 1     1.740859  1.740056  0.332931 -0.269345 -0.304420 -0.404882  0.932493
# 2     0.894046 -0.747536  0.699740 -0.223493  0.491016 -0.469809  0.507679
# 3    -0.185984 -0.655874  0.122202 -0.204106  0.528374 -0.209178  0.244851
# 4     0.478726 -0.330561 -0.519205  0.078286  0.032013 -0.444729  0.399113
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.636891 -0.204385 -1.837143  0.333735  0.535994 -0.492054 -0.627574
# 2140 -0.644373 -0.238525 -1.147906  0.966402 -0.069423 -0.440107 -0.381868
# 2141 -0.731924 -0.231757 -1.159987  1.270341 -0.152702 -0.356853 -0.643993
# 2142 -0.708904 -0.645455 -0.945511  0.465285  0.553609 -0.512440 -0.833756
# 2143 -0.688848 -0.603472 -1.057425  0.864382  0.164463 -0.468050 -0.842016
#
#             14        15        16        17        18        19
# 0    -0.332713  2.585506 -0.241655 -0.393022 -1.468364 -1.541089
# 1     1.901776  0.109704 -0.191425 -0.920133 -0.264820 -1.540621
# 2    -0.014678  1.307057  0.442543 -0.731315 -0.852687 -1.540152
# 3     0.250681  0.939709  0.341811 -0.290847 -0.906602 -1.539683
# 4     0.082223  1.138312  0.728998 -0.864319  1.529515 -1.539214
# ...        ...       ...       ...       ...       ...       ...
# 2139 -0.560207 -0.966666  0.559795 -0.148159  2.727952  1.648583
# 2140 -0.120723 -0.740490  0.054469  0.834860  1.124843  1.649051
# 2141 -0.126189 -1.105109 -0.686846  0.989862 -0.234790  1.649520
# 2142  0.041176 -0.816709 -0.492545  0.402460  1.550716  1.649989
# 2143  0.014044 -0.824533  0.738374  0.536624 -0.196902  1.650457
#
# [2144 rows x 20 columns]

# %% [markdown]
# Determination of the parameters and the number of clusters

# %%
from sklearn.cluster import KMeans

df_2020 = np.nan_to_num(df_2020, nan=0)

inertias = []

for i in range(1,13):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df_2020)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,13), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
plt.rcParams["figure.figsize"] = (10,10)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
silhouette_ann= []
for num_clusters in range(2,10):
  # initialise kmeans
  kmeans = KMeans(num_clusters)
  kmeans.fit(df_2020)
  cluster_labels = kmeans.labels_
  
# silhouette score
  silhouette_ann.append(silhouette_score(df_2020, cluster_labels))
silhouette_ann
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [0.13369610490871067,
#  0.09901063625505196,
#  0.09781365070152867,
#  0.08474130389944304,
#  0.08566857089203621,
#  0.07966897063067849,
#  0.07214314072801566,
#  0.0738120264854549]

# %%
num_clusters
# Out:
# 9

# %%
Ncluster = range(1,num_clusters)
Ncluster
silhouette_ann
# Out:
# [0.13369610490871067,
#  0.09901063625505196,
#  0.09781365070152867,
#  0.08474130389944304,
#  0.08566857089203621,
#  0.07966897063067849,
#  0.07214314072801566,
#  0.0738120264854549]

# %%
plt.plot(Ncluster,silhouette_ann,marker='s',c='k',lw=2)
plt.xlabel('Number of Clusters') 
plt.ylabel('Silhouette score') 
plt.title('Silhouette Analysis for Optimal K')
plt.show()
plt.rcParams["figure.figsize"] = (10,10)

# %%
df_2020 = pd.DataFrame(df_2020)

# %%
df_2020
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.546101  2.241058 -0.660898 -0.307513  1.752654  0.880573 -0.153229
# 1     0.139013  0.478503 -0.658511  0.991672 -0.437349 -0.230200  1.394551
# 2    -0.243728 -0.272406 -1.000414 -0.286079  0.276371  0.914706 -0.106380
# 3    -0.528882  0.118359 -0.423188 -0.462471 -0.190509  0.741725 -0.235154
# 4    -0.490862 -0.225272 -0.608355  0.040003 -0.089300  1.250576 -0.048827
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.797887  0.364219  2.205168 -0.218982  0.410353  0.681147 -0.531775
# 2140 -0.342511 -0.684942  2.247762 -0.036143  0.480687  1.228938 -0.774338
# 2141  0.011973 -1.872263  1.446574 -0.768837 -0.687605 -0.081309 -0.865120
# 2142 -0.402445 -0.605642  0.765400  0.284056  1.414825  1.135654 -0.946812
# 2143 -0.172983 -0.591239  1.871646 -0.597306 -0.345091  0.596094 -0.919260
#
#             7         8         9         10        11        12        13  \
# 0    -0.224832 -0.345541  0.691208 -0.092141  0.282056  0.119495  0.365369
# 1     1.740859  1.740056  0.332931 -0.269345 -0.304420 -0.404882  0.932493
# 2     0.894046 -0.747536  0.699740 -0.223493  0.491016 -0.469809  0.507679
# 3    -0.185984 -0.655874  0.122202 -0.204106  0.528374 -0.209178  0.244851
# 4     0.478726 -0.330561 -0.519205  0.078286  0.032013 -0.444729  0.399113
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.636891 -0.204385 -1.837143  0.333735  0.535994 -0.492054 -0.627574
# 2140 -0.644373 -0.238525 -1.147906  0.966402 -0.069423 -0.440107 -0.381868
# 2141 -0.731924 -0.231757 -1.159987  1.270341 -0.152702 -0.356853 -0.643993
# 2142 -0.708904 -0.645455 -0.945511  0.465285  0.553609 -0.512440 -0.833756
# 2143 -0.688848 -0.603472 -1.057425  0.864382  0.164463 -0.468050 -0.842016
#
#             14        15        16        17        18        19
# 0    -0.332713  2.585506 -0.241655 -0.393022 -1.468364 -1.541089
# 1     1.901776  0.109704 -0.191425 -0.920133 -0.264820 -1.540621
# 2    -0.014678  1.307057  0.442543 -0.731315 -0.852687 -1.540152
# 3     0.250681  0.939709  0.341811 -0.290847 -0.906602 -1.539683
# 4     0.082223  1.138312  0.728998 -0.864319  1.529515 -1.539214
# ...        ...       ...       ...       ...       ...       ...
# 2139 -0.560207 -0.966666  0.559795 -0.148159  2.727952  1.648583
# 2140 -0.120723 -0.740490  0.054469  0.834860  1.124843  1.649051
# 2141 -0.126189 -1.105109 -0.686846  0.989862 -0.234790  1.649520
# 2142  0.041176 -0.816709 -0.492545  0.402460  1.550716  1.649989
# 2143  0.014044 -0.824533  0.738374  0.536624 -0.196902  1.650457
#
# [2144 rows x 20 columns]

# %% [markdown]
# Implement a weighted K-means

# %%
df_2020_K = df_2020

# %% [markdown]
# 1. K-means without weight

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(df_2020)
print(kmeans)

y_kmean_3 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
df_2020
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.546101  2.241058 -0.660898 -0.307513  1.752654  0.880573 -0.153229
# 1     0.139013  0.478503 -0.658511  0.991672 -0.437349 -0.230200  1.394551
# 2    -0.243728 -0.272406 -1.000414 -0.286079  0.276371  0.914706 -0.106380
# 3    -0.528882  0.118359 -0.423188 -0.462471 -0.190509  0.741725 -0.235154
# 4    -0.490862 -0.225272 -0.608355  0.040003 -0.089300  1.250576 -0.048827
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.797887  0.364219  2.205168 -0.218982  0.410353  0.681147 -0.531775
# 2140 -0.342511 -0.684942  2.247762 -0.036143  0.480687  1.228938 -0.774338
# 2141  0.011973 -1.872263  1.446574 -0.768837 -0.687605 -0.081309 -0.865120
# 2142 -0.402445 -0.605642  0.765400  0.284056  1.414825  1.135654 -0.946812
# 2143 -0.172983 -0.591239  1.871646 -0.597306 -0.345091  0.596094 -0.919260
#
#             7         8         9         10        11        12        13  \
# 0    -0.224832 -0.345541  0.691208 -0.092141  0.282056  0.119495  0.365369
# 1     1.740859  1.740056  0.332931 -0.269345 -0.304420 -0.404882  0.932493
# 2     0.894046 -0.747536  0.699740 -0.223493  0.491016 -0.469809  0.507679
# 3    -0.185984 -0.655874  0.122202 -0.204106  0.528374 -0.209178  0.244851
# 4     0.478726 -0.330561 -0.519205  0.078286  0.032013 -0.444729  0.399113
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.636891 -0.204385 -1.837143  0.333735  0.535994 -0.492054 -0.627574
# 2140 -0.644373 -0.238525 -1.147906  0.966402 -0.069423 -0.440107 -0.381868
# 2141 -0.731924 -0.231757 -1.159987  1.270341 -0.152702 -0.356853 -0.643993
# 2142 -0.708904 -0.645455 -0.945511  0.465285  0.553609 -0.512440 -0.833756
# 2143 -0.688848 -0.603472 -1.057425  0.864382  0.164463 -0.468050 -0.842016
#
#             14        15        16        17        18        19
# 0    -0.332713  2.585506 -0.241655 -0.393022 -1.468364 -1.541089
# 1     1.901776  0.109704 -0.191425 -0.920133 -0.264820 -1.540621
# 2    -0.014678  1.307057  0.442543 -0.731315 -0.852687 -1.540152
# 3     0.250681  0.939709  0.341811 -0.290847 -0.906602 -1.539683
# 4     0.082223  1.138312  0.728998 -0.864319  1.529515 -1.539214
# ...        ...       ...       ...       ...       ...       ...
# 2139 -0.560207 -0.966666  0.559795 -0.148159  2.727952  1.648583
# 2140 -0.120723 -0.740490  0.054469  0.834860  1.124843  1.649051
# 2141 -0.126189 -1.105109 -0.686846  0.989862 -0.234790  1.649520
# 2142  0.041176 -0.816709 -0.492545  0.402460  1.550716  1.649989
# 2143  0.014044 -0.824533  0.738374  0.536624 -0.196902  1.650457
#
# [2144 rows x 20 columns]

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(df_2020)
y_kmean_7 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# 2. K-Means avec weighted pop

# %%
kmeans = KMeans(n_clusters=3)
weights = w_pop
df_2020.columns = df_2020.columns.astype(str)
kmeans.fit(df_2020, sample_weight = w_pop)
y_kmean_pop_3 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters=7)
weights = w_pop
df_2020.columns = df_2020.columns.astype(str)
kmeans.fit(df_2020, sample_weight = w_pop)
y_kmean_pop_7 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# 3. K-Means with weight on the surface

# %%
kmeans = KMeans(n_clusters=3)
weights = w_surf
df_2020.columns = df_2020.columns.astype(str)
kmeans.fit(df_2020, sample_weight = w_pop)
print(kmeans)
y_kmean_surf_3 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
kmeans = KMeans(n_clusters=7)
weights = w_surf
df_2020.columns = df_2020.columns.astype(str)
kmeans.fit(df_2020, sample_weight = w_pop)
y_kmean_surf_7 = kmeans.predict(df_2020)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_2020['cluster_3']= y_kmean_3
df_2020['cluster_7']= y_kmean_7
df_2020['cluster_pop_3']= y_kmean_pop_3
df_2020['cluster_pop_7']= y_kmean_pop_7
df_2020['cluster_surf_3']= y_kmean_surf_3
df_2020['cluster_surf_7']= y_kmean_surf_7

# %%
df_2020
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.546101  2.241058 -0.660898 -0.307513  1.752654  0.880573 -0.153229
# 1     0.139013  0.478503 -0.658511  0.991672 -0.437349 -0.230200  1.394551
# 2    -0.243728 -0.272406 -1.000414 -0.286079  0.276371  0.914706 -0.106380
# 3    -0.528882  0.118359 -0.423188 -0.462471 -0.190509  0.741725 -0.235154
# 4    -0.490862 -0.225272 -0.608355  0.040003 -0.089300  1.250576 -0.048827
# ...        ...       ...       ...       ...       ...       ...       ...
# 2139 -0.797887  0.364219  2.205168 -0.218982  0.410353  0.681147 -0.531775
# 2140 -0.342511 -0.684942  2.247762 -0.036143  0.480687  1.228938 -0.774338
# 2141  0.011973 -1.872263  1.446574 -0.768837 -0.687605 -0.081309 -0.865120
# 2142 -0.402445 -0.605642  0.765400  0.284056  1.414825  1.135654 -0.946812
# 2143 -0.172983 -0.591239  1.871646 -0.597306 -0.345091  0.596094 -0.919260
#
#              7         8         9  ...        16        17        18  \
# 0    -0.224832 -0.345541  0.691208  ... -0.241655 -0.393022 -1.468364
# 1     1.740859  1.740056  0.332931  ... -0.191425 -0.920133 -0.264820
# 2     0.894046 -0.747536  0.699740  ...  0.442543 -0.731315 -0.852687
# 3    -0.185984 -0.655874  0.122202  ...  0.341811 -0.290847 -0.906602
# 4     0.478726 -0.330561 -0.519205  ...  0.728998 -0.864319  1.529515
# ...        ...       ...       ...  ...       ...       ...       ...
# 2139 -0.636891 -0.204385 -1.837143  ...  0.559795 -0.148159  2.727952
# 2140 -0.644373 -0.238525 -1.147906  ...  0.054469  0.834860  1.124843
# 2141 -0.731924 -0.231757 -1.159987  ... -0.686846  0.989862 -0.234790
# 2142 -0.708904 -0.645455 -0.945511  ... -0.492545  0.402460  1.550716
# 2143 -0.688848 -0.603472 -1.057425  ...  0.738374  0.536624 -0.196902
#
#             19  cluster_3  cluster_7  cluster_pop_3  cluster_pop_7  \
# 0    -1.541089          2          4              1              4
# 1    -1.540621          1          1              0              2
# 2    -1.540152          2          3              1              4
# 3    -1.539683          2          2              1              5
# 4    -1.539214          2          2              1              4
# ...        ...        ...        ...            ...            ...
# 2139  1.648583          0          2              1              5
# 2140  1.649051          0          6              1              5
# 2141  1.649520          0          5              1              5
# 2142  1.649989          0          2              1              5
# 2143  1.650457          0          5              1              5
#
#       cluster_surf_3  cluster_surf_7
# 0                  1               6
# 1                  2               5
# 2                  1               6
# 3                  1               6
# 4                  1               6
# ...              ...             ...
# 2139               1               6
# 2140               1               6
# 2141               1               0
# 2142               1               6
# 2143               1               6
#
# [2144 rows x 26 columns]

# %% [markdown]
# 3. Kmeans en fonction du PCA

# %%
nostdf_2020 #avec les valeurs non-standardisées
# Out:
#       migration  migration_intern  dependency_ratio  p_new_housings  \
# 0     -0.546101          2.241058         -0.660898       -0.307513
# 1      0.139013          0.478503         -0.658511        0.991672
# 2     -0.243728         -0.272406         -1.000414       -0.286079
# 3     -0.528882          0.118359         -0.423188       -0.462471
# 4     -0.490862         -0.225272         -0.608355        0.040003
# ...         ...               ...               ...             ...
# 2139  -0.797887          0.364219          2.205168       -0.218982
# 2140  -0.342511         -0.684942          2.247762       -0.036143
# 2141   0.011973         -1.872263          1.446574       -0.768837
# 2142  -0.402445         -0.605642          0.765400        0.284056
# 2143  -0.172983         -0.591239          1.871646       -0.597306
#
#       p_new_buildings  p_individual_houses  p_foreigners   density  \
# 0            1.752654             0.880573     -0.153229 -0.224832
# 1           -0.437349            -0.230200      1.394551  1.740859
# 2            0.276371             0.914706     -0.106380  0.894046
# 3           -0.190509             0.741725     -0.235154 -0.185984
# 4           -0.089300             1.250576     -0.048827  0.478726
# ...               ...                  ...           ...       ...
# 2139         0.410353             0.681147     -0.531775 -0.636891
# 2140         0.480687             1.228938     -0.774338 -0.644373
# 2141        -0.687605            -0.081309     -0.865120 -0.731924
# 2142         1.414825             1.135654     -0.946812 -0.708904
# 2143        -0.345091             0.596094     -0.919260 -0.688848
#
#       p_social_assistance  natural_growth_1000  p_forested  p_agriculture  \
# 0               -0.345541             0.691208   -0.092141       0.282056
# 1                1.740056             0.332931   -0.269345      -0.304420
# 2               -0.747536             0.699740   -0.223493       0.491016
# 3               -0.655874             0.122202   -0.204106       0.528374
# 4               -0.330561            -0.519205    0.078286       0.032013
# ...                   ...                  ...         ...            ...
# 2139            -0.204385            -1.837143    0.333735       0.535994
# 2140            -0.238525            -1.147906    0.966402      -0.069423
# 2141            -0.231757            -1.159987    1.270341      -0.152702
# 2142            -0.645455            -0.945511    0.465285       0.553609
# 2143            -0.603472            -1.057425    0.864382       0.164463
#
#       p_unproductive  p_surf_transport  zab_2012  net_income_h  p_pop_19  \
# 0           0.119495          0.365369 -0.332713      2.585506 -0.241655
# 1          -0.404882          0.932493  1.901776      0.109704 -0.191425
# 2          -0.469809          0.507679 -0.014678      1.307057  0.442543
# 3          -0.209178          0.244851  0.250681      0.939709  0.341811
# 4          -0.444729          0.399113  0.082223      1.138312  0.728998
# ...              ...               ...       ...           ...       ...
# 2139       -0.492054         -0.627574 -0.560207     -0.966666  0.559795
# 2140       -0.440107         -0.381868 -0.120723     -0.740490  0.054469
# 2141       -0.356853         -0.643993 -0.126189     -1.105109 -0.686846
# 2142       -0.512440         -0.833756  0.041176     -0.816709 -0.492545
# 2143       -0.468050         -0.842016  0.014044     -0.824533  0.738374
#
#       p_primary_sector  p_secondary_sector    ID
# 0            -0.393022           -1.468364     1
# 1            -0.920133           -0.264820     2
# 2            -0.731315           -0.852687     3
# 3            -0.290847           -0.906602     4
# 4            -0.864319            1.529515     5
# ...                ...                 ...   ...
# 2139         -0.148159            2.727952  6806
# 2140          0.834860            1.124843  6807
# 2141          0.989862           -0.234790  6808
# 2142          0.402460            1.550716  6809
# 2143          0.536624           -0.196902  6810
#
# [2144 rows x 20 columns]

# %% [markdown]
# 1. importer les valeurs

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(df_2020) #valeurs PCA ===> en fonction des scores 
print(kmeans)

y_kmean = kmeans.predict(df_2020)
df_2020_K['cluster']= y_kmean
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
df_2020.to_csv('data_kmeansweighted.csv', index = False, sep=',')

# %% [markdown]
# ## Self-Organizing Map algorithm
