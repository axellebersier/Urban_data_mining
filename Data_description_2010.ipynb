# %% [markdown]
# <a href="https://colab.research.google.com/github/axellebersier/Urban_data_mining/blob/main/Data_description_2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Data Processing**

# %% [markdown]
# ##Data description

# %% [markdown]
# Set up and load the data

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
rnd_seed = 42
rnd_gen = np.random.default_rng(rnd_seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "dim_reduction"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import pandas as pd

url_2020 = 'https://github.com/axellebersier/Urban_data_mining/raw/main/Data/c_2010_merged.xlsx'
df_2020 = pd.read_excel(url_2020, engine='openpyxl')

# %% [markdown]
# ##Data Description 2010

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2041 entries, 0 to 2040
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             2041 non-null   int64
#  1   area_to_build_2012             2041 non-null   float64
#  2   s_infrastructure               2041 non-null   int64
#  3   s_agriculture                  2041 non-null   int64
#  4   s_forested                     2041 non-null   int64
#  5   s_improductible                2041 non-null   int64
#  6   migration                      2041 non-null   float64
#  7   migration_intern               2041 non-null   float64
#  8   dependency_ratio               2041 non-null   float64
#  9   Population                     2041 non-null   int64
#  10  new_housings                   2041 non-null   int64
#  11  new_buildings                  2041 non-null   int64
#  12  swiss_nationality_acquisition  2041 non-null   int64
#  13  n_wedding                      2041 non-null   int64
#  14  p_individual_houses            2038 non-null   float64
#  15  n_stangers                     2041 non-null   int64
#  16  density                        2041 non-null   float64
#  17  n_social_assistance            2041 non-null   int64
#  18  natural_growth                 2041 non-null   int64
#  19  commune                        2041 non-null   object
#  20  no_mut_nvlle_cmne              2041 non-null   int64
#  21  date_entree_ch                 2041 non-null   datetime64[ns]
#  22  no_mut_ancienne_cmne           713 non-null    float64
#  23  new_no_commune                 2041 non-null   int64
#  24  new_commune                    2041 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(15), object(2)
# memory usage: 398.8+ KB

# %%
df_2020.describe()
# Out:
#                 ID  area_to_build_2012  s_infrastructure  s_agriculture  \
# count  2041.000000         2041.000000       2041.000000    2041.000000
# mean   2871.367957          205.882670        304.081823    1993.831455
# std    2112.386702          393.849226        470.262428    3501.604375
# min       1.000000            0.000000          2.000000       0.000000
# 25%     791.000000           38.700000         74.000000     354.000000
# 50%    2790.000000           92.340000        164.000000     792.000000
# 75%    4811.000000          210.600000        339.000000    2140.000000
# max    6810.000000         4907.320000       5680.000000   37068.000000
#
#          s_forested  s_improductible    migration  migration_intern  \
# count   2041.000000      2041.000000  2041.000000       2041.000000
# mean    1658.616365      1450.437041    12.043209         -2.281956
# std     3239.619217      6574.407378    21.338783         47.674045
# min        0.000000         0.000000   -63.829787       -340.909091
# 25%      195.000000         4.000000     1.440922        -18.779343
# 50%      529.000000        19.000000     7.159905         -0.093538
# 75%     1534.000000       118.000000    16.435783         15.017668
# max    31353.000000     65324.000000   169.555129        321.059499
#
#        dependency_ratio     Population  ...  swiss_nationality_acquisition  \
# count       2041.000000    2041.000000  ...                    2041.000000
# mean         152.134513    6664.265556  ...                      26.534052
# std          123.135234   18086.662548  ...                     134.593728
# min           23.255814      53.000000  ...                       0.000000
# 25%           66.211330     971.000000  ...                       0.000000
# 50%          122.481233    2488.000000  ...                       4.000000
# 75%          193.665158    5840.000000  ...                      16.000000
# max         1042.164528  372857.000000  ...                    4593.000000
#
#          n_wedding  p_individual_houses     n_stangers       density  \
# count  2041.000000          2038.000000    2041.000000   2041.000000
# mean     34.870652           125.421408    1249.149437    630.841857
# std     109.312324            99.002192    5342.401879   1136.317774
# min       0.000000            12.142857       0.000000      2.200133
# 25%       4.000000            62.893425      70.000000     91.559486
# 50%      12.000000            95.969763     218.000000    236.993504
# 75%      30.000000           154.801409     813.000000    626.796345
# max    2754.000000           991.383868  113716.000000  13385.526316
#
#        n_social_assistance  natural_growth  no_mut_nvlle_cmne  \
# count          2041.000000     2041.000000        2041.000000
# mean            214.663400        7.319941        2423.618814
# std             870.087083       38.084594         776.170530
# min               0.000000     -165.000000        1033.000000
# 25%               0.000000       -3.000000        1719.000000
# 50%              30.000000        3.000000        2470.000000
# 75%             123.000000       12.000000        3107.000000
# max           18269.000000     1077.000000        3963.000000
#
#        no_mut_ancienne_cmne  new_no_commune
# count            713.000000     2041.000000
# mean            2821.489481     2871.045566
# std              681.149735     2112.110115
# min             1226.000000        1.000000
# 25%             2140.000000      791.000000
# 50%             3038.000000     2790.000000
# 75%             3291.000000     4801.000000
# max             3960.000000     6810.000000
#
# [8 rows x 22 columns]

# %%
df_2020.head()
# Out:
#     ID  area_to_build_2012  s_infrastructure  s_agriculture  s_forested  \
# 0    1               61.01                99            406         243
# 1   14              129.49               156            126          77
# 2   24               32.43                70            560         386
# 3  159              145.91               151            141          57
# 4  161              289.29               328            160         297
#
#    s_improductible  migration  migration_intern  dependency_ratio  Population  \
# 0               42   1.684447         38.180797         58.333333        1824
# 1               16   6.910388         -6.018725         67.892977        4518
# 2                0  32.710280         33.878505         56.350626         874
# 3                2   5.959684         -9.465381         71.706587        5735
# 4                0   1.577680         -6.061613         76.798825       12040
#
#    ...  n_stangers      density  n_social_assistance  natural_growth  \
# 0  ...         225   230.594185                   16              10
# 1  ...         585  1201.595745                   25              39
# 2  ...          71    85.185185                    0               4
# 3  ...         955  1657.514451                   90              20
# 4  ...        2403  1531.806616                  160              23
#
#              commune  no_mut_nvlle_cmne  date_entree_ch  no_mut_ancienne_cmne  \
# 0    Aeugst am Albis               1071      1976-11-15                   NaN
# 1  Wettswil am Albis               1070      1976-11-15                   NaN
# 2     Buch am Irchel               3293      2013-01-01                   NaN
# 3     Uetikon am See               1074      1977-03-10                   NaN
# 4           Zollikon               1493      1986-01-01                   NaN
#
#    new_no_commune        new_commune
# 0               1    Aeugst am Albis
# 1              14  Wettswil am Albis
# 2              24     Buch am Irchel
# 3             159     Uetikon am See
# 4             161           Zollikon
#
# [5 rows x 25 columns]

# %%
df_2020 =  df_2020.iloc[:,1:17]
#df_2020.head()

#df_2020 = np.as(df_2020)
#print(df_2020)

# %%
df_2020 = pd.DataFrame(df_2020)
corr_matrix_2020 = df_2020.corr()
print(corr_matrix_2020)
# Out:
#                                area_to_build_2012  s_infrastructure  \
# area_to_build_2012                       1.000000          0.968882
# s_infrastructure                         0.968882          1.000000
# s_agriculture                            0.235939          0.412239
# s_forested                               0.347078          0.504139
# s_improductible                          0.082546          0.195026
# migration                                0.322931          0.372244
# migration_intern                        -0.019139         -0.065102
# dependency_ratio                         0.260248          0.345540
# Population                               0.932158          0.891365
# new_housings                             0.834608          0.785752
# new_buildings                            0.817456          0.780997
# swiss_nationality_acquisition            0.713499          0.659998
# n_wedding                                0.885154          0.839605
# p_individual_houses                      0.259284          0.314576
# n_stangers                               0.853952          0.804394
# density                                  0.593526          0.523502
#
#                                s_agriculture  s_forested  s_improductible  \
# area_to_build_2012                  0.235939    0.347078         0.082546
# s_infrastructure                    0.412239    0.504139         0.195026
# s_agriculture                       1.000000    0.802434         0.674586
# s_forested                          0.802434    1.000000         0.729471
# s_improductible                     0.674586    0.729471         1.000000
# migration                           0.377426    0.389460         0.264285
# migration_intern                   -0.159861   -0.210495        -0.203755
# dependency_ratio                    0.472703    0.381371         0.238980
# Population                          0.115518    0.248960         0.014620
# new_housings                        0.152005    0.216849         0.044298
# new_buildings                       0.211855    0.228715         0.054493
# swiss_nationality_acquisition       0.015206    0.116596        -0.019854
# n_wedding                           0.084443    0.203626        -0.002325
# p_individual_houses                 0.339358    0.288669         0.155749
# n_stangers                          0.057080    0.237186         0.012733
# density                            -0.075505   -0.024840        -0.099516
#
#                                migration  migration_intern  dependency_ratio  \
# area_to_build_2012              0.322931         -0.019139          0.260248
# s_infrastructure                0.372244         -0.065102          0.345540
# s_agriculture                   0.377426         -0.159861          0.472703
# s_forested                      0.389460         -0.210495          0.381371
# s_improductible                 0.264285         -0.203755          0.238980
# migration                       1.000000         -0.126052          0.451848
# migration_intern               -0.126052          1.000000         -0.173609
# dependency_ratio                0.451848         -0.173609          1.000000
# Population                      0.221633         -0.026002          0.167847
# new_housings                    0.249134          0.074631          0.178667
# new_buildings                   0.250631          0.108809          0.245916
# swiss_nationality_acquisition   0.130372         -0.003889          0.045424
# n_wedding                       0.197068         -0.017663          0.132751
# p_individual_houses             0.418485         -0.097173          0.910612
# n_stangers                      0.214641         -0.016980          0.072765
# density                         0.201293          0.012310          0.236980
#
#                                Population  new_housings  new_buildings  \
# area_to_build_2012               0.932158      0.834608       0.817456
# s_infrastructure                 0.891365      0.785752       0.780997
# s_agriculture                    0.115518      0.152005       0.211855
# s_forested                       0.248960      0.216849       0.228715
# s_improductible                  0.014620      0.044298       0.054493
# migration                        0.221633      0.249134       0.250631
# migration_intern                -0.026002      0.074631       0.108809
# dependency_ratio                 0.167847      0.178667       0.245916
# Population                       1.000000      0.810869       0.733932
# new_housings                     0.810869      1.000000       0.882807
# new_buildings                    0.733932      0.882807       1.000000
# swiss_nationality_acquisition    0.856865      0.654099       0.501595
# n_wedding                        0.986196      0.787751       0.696537
# p_individual_houses              0.150917      0.163897       0.268326
# n_stangers                       0.939712      0.742776       0.609305
# density                          0.596826      0.533493       0.507444
#
#                                swiss_nationality_acquisition  n_wedding  \
# area_to_build_2012                                  0.713499   0.885154
# s_infrastructure                                    0.659998   0.839605
# s_agriculture                                       0.015206   0.084443
# s_forested                                          0.116596   0.203626
# s_improductible                                    -0.019854  -0.002325
# migration                                           0.130372   0.197068
# migration_intern                                   -0.003889  -0.017663
# dependency_ratio                                    0.045424   0.132751
# Population                                          0.856865   0.986196
# new_housings                                        0.654099   0.787751
# new_buildings                                       0.501595   0.696537
# swiss_nationality_acquisition                       1.000000   0.908605
# n_wedding                                           0.908605   1.000000
# p_individual_houses                                 0.028039   0.118738
# n_stangers                                          0.872776   0.928463
# density                                             0.440251   0.561837
#
#                                p_individual_houses  n_stangers   density
# area_to_build_2012                        0.259284    0.853952  0.593526
# s_infrastructure                          0.314576    0.804394  0.523502
# s_agriculture                             0.339358    0.057080 -0.075505
# s_forested                                0.288669    0.237186 -0.024840
# s_improductible                           0.155749    0.012733 -0.099516
# migration                                 0.418485    0.214641  0.201293
# migration_intern                         -0.097173   -0.016980  0.012310
# dependency_ratio                          0.910612    0.072765  0.236980
# Population                                0.150917    0.939712  0.596826
# new_housings                              0.163897    0.742776  0.533493
# new_buildings                             0.268326    0.609305  0.507444
# swiss_nationality_acquisition             0.028039    0.872776  0.440251
# n_wedding                                 0.118738    0.928463  0.561837
# p_individual_houses                       1.000000    0.056332  0.264545
# n_stangers                                0.056332    1.000000  0.511949
# density                                   0.264545    0.511949  1.000000

# %% [markdown]
# ##Description of the correlations for 2020

# %% [markdown]
# Correlation matrix

# %%
import seaborn as sn
import matplotlib.pyplot as plt

ax = sn.heatmap(corr_matrix_2020, annot=True)
plt.title("Heatmap of correlations")
plt.rcParams["figure.figsize"] = (20,60)
plt.show()

# %% [markdown]
# Principal component Analysis => cf code in R

# %% [markdown]
# ##Number of clusters

# %% [markdown]
# Silhouette score

# %%
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

#df_2020 <- np.asmatrix(df_2020)

df_2020.shape
scaler = StandardScaler()
stdf_2020 = scaler.fit_transform(df_2020)
print(stdf_2020)

df_2020 = pd.DataFrame(stdf_2020)
print(df_2020)

df_2020.to_csv('data_standardized_2020', index = False, sep='\t')
df_2020.shape
# Out:
# [[-0.36792804 -0.43620768 -0.4535694  ... -0.54063883 -0.19174904
#   -0.35231849]
#  [-0.19401179 -0.31496906 -0.53355234 ... -0.50238449 -0.1243471
#    0.50240679]
#  [-0.44051166 -0.49789049 -0.40957878 ... -0.57588972 -0.22058209
#   -0.48031493]
#  ...
#  [-0.02189869  0.0508738   0.7518878  ...  1.01483491 -0.20466774
#   -0.47619291]
#  [-0.02189869  0.0508738   0.7518878  ...  1.01483491 -0.20466774
#   -0.47619291]
#  [-0.27931913 -0.31496906 -0.13392328 ... -0.57871318 -0.22095654
#   -0.52161346]]
#             0         1         2         3         4         5         6   \
# 0    -0.367928 -0.436208 -0.453569 -0.437077 -0.214283 -0.485562  0.848946
# 1    -0.194012 -0.314969 -0.533552 -0.488330 -0.218238 -0.240599 -0.078401
# 2    -0.440512 -0.497890 -0.409579 -0.392925 -0.220673  0.968759  0.758680
# 3    -0.152310 -0.325604 -0.529268 -0.494505 -0.220368 -0.285162 -0.150715
# 4     0.211827  0.050874 -0.523840 -0.420404 -0.220673 -0.490567 -0.079301
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.313757 -0.289445 -0.275893 -0.175871 -0.218391 -0.421718 -0.159854
# 2037 -0.315154 -0.168207  0.189436  0.479613 -0.208045 -0.310555 -0.569208
# 2038 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2039 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2040 -0.279319 -0.314969 -0.133923 -0.073982 -0.218695 -0.368556 -0.127548
#
#             7         8         9         10        11        12        13  \
# 0    -0.761960 -0.267681  0.150194  0.042621 -0.167464 -0.282477 -0.540639
# 1    -0.684306 -0.118695 -0.205935 -0.263680 -0.108011 -0.053718 -0.502384
# 2    -0.778066 -0.320219 -0.294968 -0.438709 -0.197190 -0.245876 -0.575890
# 3    -0.653328 -0.051391 -0.311155 -0.526224  0.025757 -0.072019 -0.663024
# 4    -0.611963  0.297294  0.295884  0.173893  0.174389  0.385498 -0.822077
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.573549 -0.296272 -0.262592 -0.307438 -0.189759 -0.282477 -0.494014
# 2037 -0.625446 -0.298816 -0.303061 -0.482467 -0.174895 -0.282477 -0.669376
# 2038  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2039  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2040 -0.597912 -0.302798 -0.294968 -0.438709 -0.182327 -0.264176 -0.578713
#
#             14        15
# 0    -0.191749 -0.352318
# 1    -0.124347  0.502407
# 2    -0.220582 -0.480315
# 3    -0.055073  0.903730
# 4     0.216033  0.793075
# ...        ...       ...
# 2036 -0.216650 -0.505387
# 2037 -0.219084 -0.537329
# 2038 -0.204668 -0.476193
# 2039 -0.204668 -0.476193
# 2040 -0.220957 -0.521613
#
# [2041 rows x 16 columns]
# (2041, 16)

# %% [markdown]
# set up to do a K-Means analysis

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Data preprocessing and standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
stdf1 = scaler.fit_transform(df_2020)
print(stdf_2020)
df_2020 = pd.DataFrame(stdf_2020)
print(df_2020)
df_2020.to_csv('data_standardized', index = False, sep='\t')
df_2020.shape

from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
stdf_2020= imputer.fit_transform(stdf_2020)
# Out:
# [[-0.36792804 -0.43620768 -0.4535694  ... -0.54063883 -0.19174904
#   -0.35231849]
#  [-0.19401179 -0.31496906 -0.53355234 ... -0.50238449 -0.1243471
#    0.50240679]
#  [-0.44051166 -0.49789049 -0.40957878 ... -0.57588972 -0.22058209
#   -0.48031493]
#  ...
#  [-0.02189869  0.0508738   0.7518878  ...  1.01483491 -0.20466774
#   -0.47619291]
#  [-0.02189869  0.0508738   0.7518878  ...  1.01483491 -0.20466774
#   -0.47619291]
#  [-0.27931913 -0.31496906 -0.13392328 ... -0.57871318 -0.22095654
#   -0.52161346]]
#             0         1         2         3         4         5         6   \
# 0    -0.367928 -0.436208 -0.453569 -0.437077 -0.214283 -0.485562  0.848946
# 1    -0.194012 -0.314969 -0.533552 -0.488330 -0.218238 -0.240599 -0.078401
# 2    -0.440512 -0.497890 -0.409579 -0.392925 -0.220673  0.968759  0.758680
# 3    -0.152310 -0.325604 -0.529268 -0.494505 -0.220368 -0.285162 -0.150715
# 4     0.211827  0.050874 -0.523840 -0.420404 -0.220673 -0.490567 -0.079301
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.313757 -0.289445 -0.275893 -0.175871 -0.218391 -0.421718 -0.159854
# 2037 -0.315154 -0.168207  0.189436  0.479613 -0.208045 -0.310555 -0.569208
# 2038 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2039 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2040 -0.279319 -0.314969 -0.133923 -0.073982 -0.218695 -0.368556 -0.127548
#
#             7         8         9         10        11        12        13  \
# 0    -0.761960 -0.267681  0.150194  0.042621 -0.167464 -0.282477 -0.540639
# 1    -0.684306 -0.118695 -0.205935 -0.263680 -0.108011 -0.053718 -0.502384
# 2    -0.778066 -0.320219 -0.294968 -0.438709 -0.197190 -0.245876 -0.575890
# 3    -0.653328 -0.051391 -0.311155 -0.526224  0.025757 -0.072019 -0.663024
# 4    -0.611963  0.297294  0.295884  0.173893  0.174389  0.385498 -0.822077
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.573549 -0.296272 -0.262592 -0.307438 -0.189759 -0.282477 -0.494014
# 2037 -0.625446 -0.298816 -0.303061 -0.482467 -0.174895 -0.282477 -0.669376
# 2038  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2039  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2040 -0.597912 -0.302798 -0.294968 -0.438709 -0.182327 -0.264176 -0.578713
#
#             14        15
# 0    -0.191749 -0.352318
# 1    -0.124347  0.502407
# 2    -0.220582 -0.480315
# 3    -0.055073  0.903730
# 4     0.216033  0.793075
# ...        ...       ...
# 2036 -0.216650 -0.505387
# 2037 -0.219084 -0.537329
# 2038 -0.204668 -0.476193
# 2039 -0.204668 -0.476193
# 2040 -0.220957 -0.521613
#
# [2041 rows x 16 columns]

# %% [markdown]
# Determination of the parameters and the number of clusters

# %%
from sklearn.cluster import KMeans


inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(stdf_2020)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
silhouette_ann= []
for num_clusters in range(2,10):
  # initialise kmeans
  kmeans = KMeans(num_clusters)
  kmeans.fit(stdf_2020)
  cluster_labels = kmeans.labels_
  
# silhouette score
  silhouette_ann.append(silhouette_score(stdf_2020, cluster_labels))
silhouette_ann
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [0.8311234883560511,
#  0.6020502424555437,
#  0.5121031939525027,
#  0.5080682782415464,
#  0.37550454802551614,
#  0.3860884773032728,
#  0.3997182031891662,
#  0.2886063440356632]

# %%
num_clusters
Ncluster = range(2,10)
Ncluster
silhouette_ann
# Out:
# [0.8311234883560511,
#  0.6020502424555437,
#  0.5121031939525027,
#  0.5080682782415464,
#  0.37550454802551614,
#  0.3860884773032728,
#  0.3997182031891662,
#  0.2886063440356632]

# %%
plt.plot(Ncluster,silhouette_ann,marker='s',c='k',lw=2)
plt.xlabel('Number of Clusters') 
plt.ylabel('Silhouette score') 
plt.title('Silhouette Analysis for Optimal K')
plt.show()

# %%
df_2020 = pd.DataFrame(stdf_2020)

# %%
df_2020
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.367928 -0.436208 -0.453569 -0.437077 -0.214283 -0.485562  0.848946
# 1    -0.194012 -0.314969 -0.533552 -0.488330 -0.218238 -0.240599 -0.078401
# 2    -0.440512 -0.497890 -0.409579 -0.392925 -0.220673  0.968759  0.758680
# 3    -0.152310 -0.325604 -0.529268 -0.494505 -0.220368 -0.285162 -0.150715
# 4     0.211827  0.050874 -0.523840 -0.420404 -0.220673 -0.490567 -0.079301
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.313757 -0.289445 -0.275893 -0.175871 -0.218391 -0.421718 -0.159854
# 2037 -0.315154 -0.168207  0.189436  0.479613 -0.208045 -0.310555 -0.569208
# 2038 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2039 -0.021899  0.050874  0.751888  0.484553 -0.220064 -0.192500 -0.493297
# 2040 -0.279319 -0.314969 -0.133923 -0.073982 -0.218695 -0.368556 -0.127548
#
#             7         8         9         10        11        12        13  \
# 0    -0.761960 -0.267681  0.150194  0.042621 -0.167464 -0.282477 -0.540639
# 1    -0.684306 -0.118695 -0.205935 -0.263680 -0.108011 -0.053718 -0.502384
# 2    -0.778066 -0.320219 -0.294968 -0.438709 -0.197190 -0.245876 -0.575890
# 3    -0.653328 -0.051391 -0.311155 -0.526224  0.025757 -0.072019 -0.663024
# 4    -0.611963  0.297294  0.295884  0.173893  0.174389  0.385498 -0.822077
# ...        ...       ...       ...       ...       ...       ...       ...
# 2036 -0.573549 -0.296272 -0.262592 -0.307438 -0.189759 -0.282477 -0.494014
# 2037 -0.625446 -0.298816 -0.303061 -0.482467 -0.174895 -0.282477 -0.669376
# 2038  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2039  0.462910 -0.249486 -0.246404 -0.176166 -0.167464 -0.245876  1.014835
# 2040 -0.597912 -0.302798 -0.294968 -0.438709 -0.182327 -0.264176 -0.578713
#
#             14        15
# 0    -0.191749 -0.352318
# 1    -0.124347  0.502407
# 2    -0.220582 -0.480315
# 3    -0.055073  0.903730
# 4     0.216033  0.793075
# ...        ...       ...
# 2036 -0.216650 -0.505387
# 2037 -0.219084 -0.537329
# 2038 -0.204668 -0.476193
# 2039 -0.204668 -0.476193
# 2040 -0.220957 -0.521613
#
# [2041 rows x 16 columns]

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(stdf1)
print(kmeans)

y_kmean = kmeans.predict(stdf1)
df['cluster']= y_kmean
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f7c01d692cd2> in <module>
#       1 kmeans = KMeans(n_clusters=5)
# ----> 2 kmeans.fit(stdf1)
#       3 print(kmeans)
#       4
#       5 y_kmean = kmeans.predict(stdf1)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1415         self._validate_params()
#    1416
# -> 1417         X = self._validate_data(
#    1418             X,
#    1419             accept_sparse="csr",
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     544             raise ValueError("Validation should be done on X, y or both.")
#     545         elif not no_val_X and no_val_y:
# --> 546             X = check_array(X, input_name="X", **check_params)
#     547             out = X
#     548         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# Same for 2010

# %% [markdown]
# ## Self-Organizing Map algorithm

# %% [markdown]
# The analysis of the Self-Organizing Map algorithm has been done with R with the help of the code of Marj Tonini. Following his request, I won't make this code public. Thus, I will present the different steps and do not hesitate to write me if additional information is needed.
#
# 1. Load the library 'kohonen'.
# 2. Set up the model (defining the grid of the som, convert the data into a matrix.
# 3. Apply the som algorithm.
# 4. Plot the heatmaps with the type "property" of the som.
# 5. Assign a number to each cluster.
# 6. Describe the data repartition into each clusters
